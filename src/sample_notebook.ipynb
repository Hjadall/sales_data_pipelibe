# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
from databricks.connect import DatabricksSession

spark = DatabricksSession.builder.serverless().profile("dev").getOrCreate()

df = spark.read.table("samples.nyctaxi.trips")
df.show(5)
# Out:
# ---------------------------------------------------------------------------
# DuplicateSectionError                     Traceback (most recent call last)
# Cell In[1], line 3
#       1 from databricks.connect import DatabricksSession
#       2
# ----> 3 spark = DatabricksSession.builder.serverless().profile("dev").getOrCreate()
#       4
#       5 df = spark.read.table("samples.nyctaxi.trips")
#       6 df.show(5)
#
# File ~/DAB's/sales_data/databricks_connect_env/lib/python3.11/site-packages/databricks/connect/session.py:405, in DatabricksSession.Builder.getOrCreate(self)
#     402 if self._cluster_id is not None and self._serverless_mode is True:
#     403     raise Exception("Can't set both cluster id and serverless.")
# --> 405 config = Config(
#     406     host=self._host,
#     407     token=self._token,
#     408     profile=self._profile,
#     409 )
#     410 if self._serverless_mode:
#     411     config.as_dict().pop("cluster_id", None)
#
# File ~/DAB's/sales_data/databricks_connect_env/lib/python3.11/site-packages/databricks/sdk/config.py:314, in Config.__init__(self, credentials_provider, credentials_strategy, product, product_version, clock, custom_headers, **kwargs)
#     312 self._set_inner_config(kwargs)
#     313 self._load_from_env()
# --> 314 self._known_file_config_loader()
#     315 self._fix_host_if_needed()
#     316 self._resolve_host_metadata()
#
# File ~/DAB's/sales_data/databricks_connect_env/lib/python3.11/site-packages/databricks/sdk/config.py:774, in Config._known_file_config_loader(self)
#     772     return
#     773 ini_file = configparser.ConfigParser()
# --> 774 ini_file.read(config_path)
#     775 # In Go SDK, we skip merging the profile with DEFAULT section, though Python's ConfigParser.items()
#     776 # is returning profile key-value pairs _including those from DEFAULT_. This is not what we expect
#     777 # from Unified Auth test suite at the moment. Hence, the private variable access.
#     778 # See: https://docs.python.org/3/library/configparser.html#mapping-protocol-access
#     779 profile, is_fallback = self._resolve_profile(self.profile, ini_file)
#
# File /usr/lib/python3.11/configparser.py:713, in RawConfigParser.read(self, filenames, encoding)
#     711 try:
#     712     with open(filename, encoding=encoding) as fp:
# --> 713         self._read(fp, filename)
#     714 except OSError:
#     715     continue
#
# File /usr/lib/python3.11/configparser.py:1087, in RawConfigParser._read(self, fp, fpname)
#    1085 if sectname in self._sections:
#    1086     if self._strict and sectname in elements_added:
# -> 1087         raise DuplicateSectionError(sectname, fpname,
#    1088                                     lineno)
#    1089     cursect = self._sections[sectname]
#    1090     elements_added.add(sectname)
#
# DuplicateSectionError: While reading from PosixPath('/home/crazyfly/.databrickscfg') [line 20]: section 'dev' already exists

# %%
import sys

sys.path.append("../src")
from sales_data import taxis

taxis.find_all_taxis().show(10)
taxis.find_all_taxis().count()
